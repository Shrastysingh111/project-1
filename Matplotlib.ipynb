# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
c=["r",'y', "g",'b']
plt.bar(x,y,color = c)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[5,6,7,8]
c=["r",'y', "g",'b']
plt.bar(x,y,color = c)
plt.show()

# %%
plt.xlabel("Numbers of students marks")
plt.ylabel("Numbers of Students")
plt.title("Total Numbers of student")
plt.bar(x,y,color = c)
plt.show()

# %%
plt.xlabel("No. of students marks" , fontsize = 15 , fontstyle = )
plt.ylabel("No.of Students" , fontsize = 15)
plt.title("Total no. of student" , fontsize = 15)
plt.bar(x,y,color = c)
plt.show()

# %%
plt.xlabel("No. of students marks" , fontsize = 15)
plt.ylabel("No.of Students" , fontsize = 15)
plt.title("Total no. of student" , fontsize = 15)
plt.bar(x,y,color = c , width=0.4)
plt.show()
